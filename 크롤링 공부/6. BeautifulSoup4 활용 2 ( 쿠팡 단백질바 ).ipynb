# %% [markdown]
# ## 활용 1

# %% [markdown]
# GET
# ?minPrice=1000&maxPrice=100000&page=1 이런식으로 값을 보내고 서버에서 맞게 페이지 반환 받는
#
#  : 큰데이터 보낼 수 X
#
# POST
#
#  : 보안데이터는 POST 방식으로 숨겨 보내기 가능/ 데이터 크기 제한 X / 회원가입 및 게시판 포스팅 등

# %%
import requests
import re
from bs4 import BeautifulSoup
# Out:
# C:\Users\meegu\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42","Accept-Language": "ko-KR,ko;q=0.8,en-US;q=0.5,en;q=0.3" }

# %%
url= 'https://www.coupang.com/np/search?q=%EB%8B%A8%EB%B0%B1%EC%A7%88%EB%B0%94&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=6&backgroundColor='

# %%
res = requests.get(url,headers=headers)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")

# %%
items = soup.find_all("li",attrs={"class":re.compile("^search-product")})

# %%
print(items[0].find("div",attrs={"class":"name"}).get_text())
# Out:
# 프로틴방앗간 하루단백바 제트 초코케이크맛, 40g, 12개

# %% [markdown]
# ## 활용 2

# %%
for item in items:
    name = item.find("div",attrs={"class":"name"}).get_text() # 제품명
    price = item.find("strong", attrs={"class":"price-value"}).get_text()#가격
    
    rate = item.find("em", attrs={"class":"rating"}) # 평점
    if rate:
        rate = rate.get_text()
    else:
        rate = "평점없음"
    
    rate_cnt = item.find("span", attrs={"class":"rating-total-count"}) #평점수
    if rate_cnt:
        rate_cnt = rate_cnt.get_text()
    else:
        rate_cnt  = "평점 수 없음"
    
    print(name, price, rate, rate_cnt)
# Out:
# 닥터유 단백질바 한입쏙, 10g, 38개입 12,240 5.0 (20911)
# 곰곰 단백질바, 50g, 12개입 13,840 5.0 (42354)
# 미트리 프로틴바 카카오초코, 40g, 20개 27,450 4.5 (1608)
# 닥터유 프로 단백질 바, 560g, 1개 17,230 4.5 (418)
# 미트리 프로틴바 2종 혼합, 02_프로틴바 2종 혼합 20개(각10개) 24,800 4.5 (470)
# 켈로그 레드베리 시리얼 에너지바, 25g, 12개 6,990 4.5 (11780)
# 닥터유 단백질바 주머니쏙, 34g, 12개 9,900 5.0 (13811)
# 심플잇 단백질바 12p, 50g, 24개 18,630 5.0 (3358)
# 프로틴방앗간 하루단백바 카카오, 45g, 10개 27,290 4.5 (368)
# 곰곰 단백질바 미니사이즈, 10g, 48개입 10,990 5.0 (3208)
# 미트리 프로틴바 그레인넛츠, 40g, 20개 27,450 4.5 (317)
# 씨알로 1+1 79콘요구르트바 식물성단백질바 스포츠파워바 식사대용 다이어트간식 씨리얼바, 식물성단백질바 1+1 (24개) 17,900 4.5 (230)
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 (42354)
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 (3907)
#
#                                                         엄마사랑 아침이 든든한 시리얼 영양바, 25g, 20개입
# ...

# %% [markdown]
# ## 활용 3

# %% [markdown]
# 광고 상품 제외

# %%
for item in items:
    
    #광고 제품 제외
    ad_badge = item.find("span",attrs={"class":"ad-badge-text"})
    if ad_badge:
        print("  <광고 상품 제외 합니다.>")
        continue
    
    name = item.find("div",attrs={"class":"name"}).get_text() # 제품명
    price = item.find("strong", attrs={"class":"price-value"}).get_text()#가격
    
    rate = item.find("em", attrs={"class":"rating"}) # 평점
    if rate:
        rate = rate.get_text()
    else:
        rate = "평점없음"
    
    rate_cnt = item.find("span", attrs={"class":"rating-total-count"}) #평점수
    if rate_cnt:
        rate_cnt = rate_cnt.get_text()
    else:
        rate_cnt  = "평점 수 없음"
    
    print(name, price, rate, rate_cnt)
# Out:
# 닥터유 단백질바 한입쏙, 10g, 38개입 12,240 5.0 (20911)
# 곰곰 단백질바, 50g, 12개입 13,840 5.0 (42354)
#   <광고 상품 제외 합니다.>
# 닥터유 프로 단백질 바, 560g, 1개 17,230 4.5 (418)
#   <광고 상품 제외 합니다.>
#   <광고 상품 제외 합니다.>
# 닥터유 단백질바 주머니쏙, 34g, 12개 9,900 5.0 (13811)
# 심플잇 단백질바 12p, 50g, 24개 18,630 5.0 (3358)
#   <광고 상품 제외 합니다.>
# 곰곰 단백질바 미니사이즈, 10g, 48개입 10,990 5.0 (3208)
#   <광고 상품 제외 합니다.>
#   <광고 상품 제외 합니다.>
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 (42354)
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 (3907)
#
#                                                         엄마사랑 아침이 든든한 시리얼 영양바, 25g, 20개입
#                                                      8,720 4.5 (13922)
#
#                                                         곰곰 레드베리 에너지바, 25g, 20개입
# ...

# %% [markdown]
# 평점 높은순/ 평점 많은순?

# %%
for item in items:
    
    #광고 제품 제외
    ad_badge = item.find("span",attrs={"class":"ad-badge-text"})
    if ad_badge:
        print("  <광고 상품 제외 합니다.>")
        continue
    
    name = item.find("div",attrs={"class":"name"}).get_text() # 제품명
    price = item.find("strong", attrs={"class":"price-value"}).get_text()#가격
    
    #리뷰 50개 이상, 평점 4.5이상되는 것만 조회
    rate = item.find("em", attrs={"class":"rating"}) # 평점
    if rate:
        rate = rate.get_text()
    else:
        print(" <평점 없는 상품 제외합니다.>")
        continue
    
    rate_cnt = item.find("span", attrs={"class":"rating-total-count"}) #평점수
    if rate_cnt:
        rate_cnt = rate_cnt.get_text()
        rate_cnt = rate_cnt[1:-1]
        print("리뷰 수" , rate_cnt)
    else:
        print(" <평점 없는 상품 제외합니다.>")
        continue
    
    if float(rate) >= 4.5 and int(rate_cnt) >= 50 :
        print(name, price, rate, rate_cnt)
# Out:
# 리뷰 수 20911
# 닥터유 단백질바 한입쏙, 10g, 38개입 12,240 5.0 20911
# 리뷰 수 42354
# 곰곰 단백질바, 50g, 12개입 13,840 5.0 42354
#   <광고 상품 제외 합니다.>
# 리뷰 수 418
# 닥터유 프로 단백질 바, 560g, 1개 17,230 4.5 418
#   <광고 상품 제외 합니다.>
#   <광고 상품 제외 합니다.>
# 리뷰 수 13811
# 닥터유 단백질바 주머니쏙, 34g, 12개 9,900 5.0 13811
# 리뷰 수 3358
# 심플잇 단백질바 12p, 50g, 24개 18,630 5.0 3358
#   <광고 상품 제외 합니다.>
# 리뷰 수 3208
# 곰곰 단백질바 미니사이즈, 10g, 48개입 10,990 5.0 3208
#   <광고 상품 제외 합니다.>
#   <광고 상품 제외 합니다.>
# 리뷰 수 42354
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 42354
# 리뷰 수 3907
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 3907
# 리뷰 수 13922
#
#                                                         엄마사랑 아침이 든든한 시리얼 영양바, 25g, 20개입
#                                                      8,720 4.5 13922
# 리뷰 수 7046
#
# ...

# %% [markdown]
# 닥터유 제품은 안사요 !

# %%
for item in items:
    
    #광고 제품 제외
    ad_badge = item.find("span",attrs={"class":"ad-badge-text"})
    if ad_badge:
        print("  <광고 상품 제외 합니다.>")
        continue
    
    # 닥터유 제품은 안사요
    name = item.find("div",attrs={"class":"name"}).get_text() # 제품명
    if "닥터유" in name:
        print(" <닥터유 제품 제외합니다.>")
        continue
    
    price = item.find("strong", attrs={"class":"price-value"}).get_text()#가격
    
    #리뷰 50개 이상, 평점 4.5이상되는 것만 조회
    rate = item.find("em", attrs={"class":"rating"}) # 평점
    if rate:
        rate = rate.get_text()
    else:
        print(" <평점 없는 상품 제외합니다.>")
        continue
    
    rate_cnt = item.find("span", attrs={"class":"rating-total-count"}) #평점수
    if rate_cnt:
        rate_cnt = rate_cnt.get_text()
        rate_cnt = rate_cnt[1:-1]
    else:
        print(" <평점 없는 상품 제외합니다.>")
        continue
    
    if float(rate) >= 4.5 and int(rate_cnt) >= 50 :
        print(name, price, rate, rate_cnt)
# Out:
#  <닥터유 제품 제외합니다.>
# 곰곰 단백질바, 50g, 12개입 13,840 5.0 42354
#   <광고 상품 제외 합니다.>
#  <닥터유 제품 제외합니다.>
#   <광고 상품 제외 합니다.>
#   <광고 상품 제외 합니다.>
#  <닥터유 제품 제외합니다.>
# 심플잇 단백질바 12p, 50g, 24개 18,630 5.0 3358
#   <광고 상품 제외 합니다.>
# 곰곰 단백질바 미니사이즈, 10g, 48개입 10,990 5.0 3208
#   <광고 상품 제외 합니다.>
#   <광고 상품 제외 합니다.>
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 42354
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 3907
#
#                                                         엄마사랑 아침이 든든한 시리얼 영양바, 25g, 20개입
#                                                      8,720 4.5 13922
#
#                                                         곰곰 레드베리 에너지바, 25g, 20개입
#                                                      9,990 4.5 7046
#  <닥터유 제품 제외합니다.>
#  <닥터유 제품 제외합니다.>
#
# ...

# %% [markdown]
# 최근 5개 페이지에서요

# %%
for i in range(1,6):
    print("페이지 :" ,i)
    url= 'https://www.coupang.com/np/search?q=%EB%8B%A8%EB%B0%B1%EC%A7%88%EB%B0%94&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page={}&rocketAll=false&searchIndexingToken=1=6&backgroundColor='.format(i)
    for item in items:
  
        #광고 제품 제외
        ad_badge = item.find("span",attrs={"class":"ad-badge-text"})
        if ad_badge:
            print("  <광고 상품 제외 합니다.>")
            continue
    
        # 닥터유 제품은 안사요
        name = item.find("div",attrs={"class":"name"}).get_text() # 제품명
        if "닥터유" in name:
            print(" <닥터유 제품 제외합니다.>")
            continue

        price = item.find("strong", attrs={"class":"price-value"}).get_text()#가격

        #리뷰 50개 이상, 평점 4.5이상되는 것만 조회
        rate = item.find("em", attrs={"class":"rating"}) # 평점
        if rate:
            rate = rate.get_text()
        else:
            print(" <평점 없는 상품 제외합니다.>")
            continue

        rate_cnt = item.find("span", attrs={"class":"rating-total-count"}) #평점수
        if rate_cnt:
            rate_cnt = rate_cnt.get_text()
            rate_cnt = rate_cnt[1:-1]
        else:
            print(" <평점 없는 상품 제외합니다.>")
            continue

        if float(rate) >= 4.5 and int(rate_cnt) >= 50 :
            print(name, price, rate, rate_cnt)
# Out:
# 페이지 : 1
#  <닥터유 제품 제외합니다.>
# 곰곰 단백질바, 50g, 12개입 13,840 5.0 42354
#   <광고 상품 제외 합니다.>
#  <닥터유 제품 제외합니다.>
#   <광고 상품 제외 합니다.>
#   <광고 상품 제외 합니다.>
#  <닥터유 제품 제외합니다.>
# 심플잇 단백질바 12p, 50g, 24개 18,630 5.0 3358
#   <광고 상품 제외 합니다.>
# 곰곰 단백질바 미니사이즈, 10g, 48개입 10,990 5.0 3208
#   <광고 상품 제외 합니다.>
#   <광고 상품 제외 합니다.>
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 42354
#
#                                                         곰곰 단백질바, 50g, 12개입
#                                                      13,840 5.0 3907
#
#                                                         엄마사랑 아침이 든든한 시리얼 영양바, 25g, 20개입
#                                                      8,720 4.5 13922
#
#                                                         곰곰 레드베리 에너지바, 25g, 20개입
#                                                      9,990 4.5 7046
#  <닥터유 제품 제외합니다.>
#  <닥터유 제품 제외합니다.>
#
# ...

# %%
for i in range(1,6):
    print("페이지 :" ,i)
    url= 'https://www.coupang.com/np/search?q=%EB%8B%A8%EB%B0%B1%EC%A7%88%EB%B0%94&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page={}&rocketAll=false&searchIndexingToken=1=6&backgroundColor='.format(i)
    for item in items:
  
        #광고 제품 제외
        ad_badge = item.find("span",attrs={"class":"ad-badge-text"})
        if ad_badge:
            #print("  <광고 상품 제외 합니다.>")
            continue
    
        # 닥터유 제품은 안사요
        name = item.find("div",attrs={"class":"name"}).get_text() # 제품명
        if "닥터유" in name:
            #print(" <닥터유 제품 제외합니다.>")
            continue

        price = item.find("strong", attrs={"class":"price-value"}).get_text()#가격

        #리뷰 50개 이상, 평점 4.5이상되는 것만 조회
        rate = item.find("em", attrs={"class":"rating"}) # 평점
        if rate:
            rate = rate.get_text()
        else:
            #print(" <평점 없는 상품 제외합니다.>")
            continue

        rate_cnt = item.find("span", attrs={"class":"rating-total-count"}) #평점수
        if rate_cnt:
            rate_cnt = rate_cnt.get_text()
            rate_cnt = rate_cnt[1:-1]
        else:
            #print(" <평점 없는 상품 제외합니다.>")
            continue

        link = item.find("a", attrs={"class": "search-product-link"})["href"]    
        if float(rate) >= 4.5 and int(rate_cnt) >= 50 :
            print(f"제품명 : {name}")
            print(f"가격 : {price}")
            print(f"평점 : {rate}점 ({rate_cnt}개)")
            print("바로가기 : {}".format('https://www.coupang.com' + link))
            print("-"*100)
# Out:
# 페이지 : 1
# 제품명 : 곰곰 단백질바, 50g, 12개입
# 가격 : 13,840
# 평점 : 5.0점 (42354개)
# 바로가기 : https://www.coupang.com/vp/products/332471584?itemId=1062234467&vendorItemId=5541640992&pickType=COU_PICK
# ----------------------------------------------------------------------------------------------------
# 제품명 : 심플잇 단백질바 12p, 50g, 24개
# 가격 : 18,630
# 평점 : 5.0점 (3358개)
# 바로가기 : https://www.coupang.com/vp/products/5855813090?itemId=10202917497&vendorItemId=80524803555
# ----------------------------------------------------------------------------------------------------
# 제품명 : 곰곰 단백질바 미니사이즈, 10g, 48개입
# 가격 : 10,990
# 평점 : 5.0점 (3208개)
# 바로가기 : https://www.coupang.com/vp/products/5836348958?itemId=10115318535&vendorItemId=77398106862
# ----------------------------------------------------------------------------------------------------
# 제품명 :
#                                                         곰곰 단백질바, 50g, 12개입
#
# 가격 : 13,840
# 평점 : 5.0점 (42354개)
# ...
