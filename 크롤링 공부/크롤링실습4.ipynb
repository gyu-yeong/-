# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time
import openpyxl

# %% [markdown]
# ### 목표: 네이버 쇼핑인사이트 top 500 불러오기

# %%
customService = Service(ChromeDriverManager().install())
customOption = Options()
browser = webdriver.Chrome(service = customService, options = customOption)

URL = 'https://datalab.naver.com/shoppingInsight/sCategory.naver'
browser.get(URL)
browser.implicitly_wait(10)

# %% [markdown]
# #### 불러올 제품 선택

# %%
# 1분류, 2분류, 3분류, 4분류에 넣을 키워드 선택

class1 = '식품'
class2 = ''
class3 = ''
class4 = ''

#class1
browser.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/span').click()
browser.find_element(By.XPATH, f'//div[2]/div/div[1]/div/div/div[1]/div/div[1]/ul/li/a[contains(text(), "{class1}")]').click()

#class2
if class2 != '':
    browser.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[2]/span').click()
    browser.find_element(By.XPATH, f'//div[2]/div/div[1]/div/div/div[1]/div/div[2]/ul/li/a[contains(text(), "{class2}")]').click()

#class3
if class3 != '':
    browser.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[3]/span').click()
    browser.find_element(By.XPATH, f'//div[2]/div/div[1]/div/div/div[1]/div/div[3]/ul/li/a[contains(text(), "{class3}")]').click()

#class4
if class4 != '':
    browser.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[4]/span').click()
    browser.find_element(By.XPATH, f'//div[2]/div/div[1]/div/div/div[1]/div/div[4]/ul/li/a[contains(text(), "{class4}")]').click()

#조회
browser.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[1]/div/a').click()
time.sleep(3)

# %%
#엑셀 모듈에서 파일 -> 시트 객체 생성
xlsxFile = openpyxl.Workbook()
xlsxSheet = xlsxFile.active
xlsxSheet.cell(row=1,column=1).value='rank'
xlsxSheet.cell(row=1,column=2).value='keyword'

# 2중 for문을 활용해 top500 가져오기
for i in range(25): # 이유: 1~20위까지만 나오고, 이게 1~25개 존재하는 방식으로 500개 표시됨
    for j in range(1, 21, 1):
        keyword = browser.find_element(By.XPATH, f'//*[@id="content"]/div[2]/div/div[2]/div[2]/div/div/div[1]/ul/li[{j}]/a').text # 키워드 가져오기
        print(keyword)
        keyword = keyword.split('\n') # 키워드간 칸 띄우기

        xlsxSheet.cell(row = ((i*20 + j)+1), column = 1).value = (i*20 + j) # 순위
        xlsxSheet.cell(row = ((i*20 + j)+1), column = 2).value = keyword[1] # 순위별 키워드

    browser.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[2]/div[2]/div/div/div[2]/div/a[2]').click() # 다음 페이지로 넘겨주기
    time.sleep(3)


#엑셀 파일 저장
xlsxFile.save('C:/박규영/2023크롤링공부/크롤링(개발자유머)/쇼핑인사이트top500.xlsx')
# Out:
# 1
# 닭가슴살
# 2
# 오메가3
# 3
# 사과
# 4
# 쌀20kg
# 5
# 먹태깡
# 6
# 글루타치온
# 7
# 유산균
# 8
# 김치
# 9
# 복숭아
# 10
# 아르기닌
# 11
# 맥심모카골드
# 12
# 콜라겐
# 13
# 꽃게
# 14
# 깔라만시
# 15
# 전복
# 16
# 쌀10kg
# 17
# 수향미10kg
# 18
# 오쏘몰이뮨
# 19
# 샤인머스켓
# 20
# 정관장에브리타임
# 21
# 밀크씨슬
# 22
# 비타민c
# 23
# 생수
# 24
# 조선호텔김치
# 25
# 옥수수
# 26
# 추석선물세트
# 27
# 고구마
# 28
# 노가리칩
# 29
# 고려은단비타민c1000
# 30
# 소금
# 31
# 비타민d
# 32
# 수향미
# 33
# 콘드로이친
# 34
# 단백질보충제
# 35
# 토마토
# 36
# 카무트효소
# 37
# 커피믹스
# 38
# 비오틴
# 39
# 루테인
# 40
# 스팸
# 41
# 종합비타민
# 42
# 마그네슘
# 43
# bnr17유산균
# 44
# 콘드로이친1200
# 45
# 수박
# 46
# 쌀
# 47
# 효소
# 48
# 멸균우유
# 49
# 두유
# 50
# 정관장
# 51
# 약과
# 52
# 락토핏
# 53
# la갈비
# 54
# 콤부차
# 55
# 햇반
# 56
# 카누
# 57
# 멀티비타민
# 58
# 신라면더레드
# 59
# 무화과
# 60
# 홍삼
# 61
# 도라지배즙
# 62
# 하이뮨
# 63
# 천일염
# 64
# 천일염20kg
# 65
# 루테인지아잔틴
# 66
# 학가산김치
# 67
# 스팸선물세트
# 68
# 포도
# 69
# 탄산수
# 70
# 비에날씬유산균
# 71
# 프로폴리스
# 72
# 삼다수
# 73
# 양배추즙
# 74
# 이노시톨
# 75
# 오트밀
# 76
# 질유산균
# 77
# 참치캔
# 78
# 맥심화이트골드
# 79
# 하이뮨프로틴밸런스
# 80
# 그릭요거트
# 81
# 폴리코사놀
# 82
# 뉴케어구수한맛
# 83
# ...
